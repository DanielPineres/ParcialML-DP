# %% [markdown]
# Ejercicio 4. Analisis exploratorio de datos.

# %% [markdown]
# 1. Wind Speed

# %%
#Lectura de datos 
import warnings
warnings.filterwarnings('ignore')
import pandas as pd 
load_path= r"C:\Users\Tripp\Downloads\data_treino_dv_df_2000_2010.csv"
df = pd.read_csv(load_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87693 entries, 0 to 87692
# Data columns (total 13 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   HORA (UTC)                                             87693 non-null  object
#  1   VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))             87693 non-null  float64
#  2   VENTO, VELOCIDADE HORARIA (m/s)                        87693 non-null  float64
#  3   UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               87693 non-null  float64
#  4   UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               87693 non-null  float64
#  5   TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)         87693 non-null  float64
#  6   TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)         87693 non-null  float64
#  7   UMIDADE RELATIVA DO AR, HORARIA (%)                    87693 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['HORA (UTC)', 'VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))',
#        'VENTO, VELOCIDADE HORARIA (m/s)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)',
#        'TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRECIPITAï¿½ï¿½O TOTAL, HORï¿½RIO (mm)', 'VENTO, RAJADA MAXIMA (m/s)',
#        'PRESSï¿½O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSï¿½O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)'],
#       dtype='object')

# %%
#Reduccion de nombres extensos en columnas 

columns = {
    "viejo": [
        'HORA (UTC)', 
        'VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))',
        'VENTO, VELOCIDADE HORARIA (m/s)',
        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
        'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)',
        'TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)',
        'UMIDADE RELATIVA DO AR, HORARIA (%)',
        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
        'PRECIPITAï¿½ï¿½O TOTAL, HORï¿½RIO (mm)', 
        'VENTO, RAJADA MAXIMA (m/s)',
        'PRESSï¿½O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
        'PRESSï¿½O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)'
    ],
    "nuevo": [
        "hora",
        "direccion horaria viento",
        "velocidad horaria viento",
        "unidad real max hora",
        "unidad real min hora",
        "temperatura max hora",
        "temperatura min hora",
        "unidad relativa",
        "presion atm",
        "precipitacion total",
        "viento maximo",
        "presion atm max",
        "presion min hora"
    ]
}
new_df= df.rename(columns=dict(zip(columns["viejo"],columns["nuevo"])))

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87693 entries, 0 to 87692
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   hora                      87693 non-null  object
#  1   direccion horaria viento  87693 non-null  float64
#  2   velocidad horaria viento  87693 non-null  float64
#  3   unidad real max hora      87693 non-null  float64
#  4   unidad real min hora      87693 non-null  float64
#  5   temperatura max hora      87693 non-null  float64
#  6   temperatura min hora      87693 non-null  float64
#  7   unidad relativa           87693 non-null  float64
#  8   presion atm               87693 non-null  float64
#  9   precipitacion total       87693 non-null  float64
#  10  viento maximo             87693 non-null  float64
#  11  presion atm max           87693 non-null  float64
#  12  presion min hora          87693 non-null  float64
# dtypes: float64(12), object(1)
# ...

# %%
#Numero de observaciones, media, desviacion estandar, minimo, maximo, cuartiles.
new_df.describe()
# Out:
#        direccion horaria viento  velocidad horaria viento  \
# count              87693.000000              87693.000000
# mean                   0.405810                  2.466192
# std                    0.686247                  1.313968
# min                   -1.000000                  0.000000
# 25%                   -0.156434                  1.500000
# 50%                    0.788011                  2.400000
# 75%                    0.970296                  3.400000
# max                    1.000000                 10.000000
#
#        unidad real max hora  unidad real min hora  temperatura max hora  \
# count          87693.000000          87693.000000          87693.000000
# mean              69.058465             63.176194             21.921264
# std               19.640222             20.166336              3.721386
# min               12.000000             10.000000              9.200000
# 25%               54.000000             48.000000             19.200000
# ...

# %%
#Conteo de datos faltantes
new_df.isnull().sum()
# Out:
# hora                        0
# direccion horaria viento    0
# velocidad horaria viento    0
# unidad real max hora        0
# unidad real min hora        0
# temperatura max hora        0
# temperatura min hora        0
# unidad relativa             0
# presion atm                 0
# precipitacion total         0
# viento maximo               0
# presion atm max             0
# presion min hora            0
# dtype: int64

# %%
(new_df.isnull().sum()/(len(new_df)))*100
# Out:
# hora                        0.0
# direccion horaria viento    0.0
# velocidad horaria viento    0.0
# unidad real max hora        0.0
# unidad real min hora        0.0
# temperatura max hora        0.0
# temperatura min hora        0.0
# unidad relativa             0.0
# presion atm                 0.0
# precipitacion total         0.0
# viento maximo               0.0
# presion atm max             0.0
# presion min hora            0.0
# dtype: float64

# %%
new_df.columns
# Out:
# Index(['hora', 'direccion horaria viento', 'velocidad horaria viento',
#        'unidad real max hora', 'unidad real min hora', 'temperatura max hora',
#        'temperatura min hora', 'unidad relativa', 'presion atm',
#        'precipitacion total', 'viento maximo', 'presion atm max',
#        'presion min hora'],
#       dtype='object')

# %%
#Histograma o diagrama de barras para la variable respuesta e independiente ( velocidad horaria del viento (m/s))
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.distplot(new_df['velocidad horaria viento'],kde_kws={"lw": 3}, bins = 50)
plt.xlabel("Velocidades")
plt.title("Velocidad del viento horaria")
# Out:
# Text(0.5, 1.0, 'Velocidad del viento horaria')

# %%
corr_matrix = new_df.drop(["hora"], axis=1).corr()
corr_matrix.shape
# Out:
# (12, 12)

# %%
#Matriz de correlacion para escogencia de variables independientes 
import numpy as np
sns.set(font_scale=1.8)
plt.figure(figsize=(20,20))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))   
sns.heatmap(corr_matrix, mask=mask, cbar=True, fmt='.1f', annot=True, annot_kws={'size': 15}, cmap='coolwarm');

# %%
sns.set(font_scale=1.8)
plt.figure(figsize=(30,30))

columns=['temperatura min hora','unidad real min hora','velocidad horaria viento','presion atm max']
fig, axes = plt.subplots(1,4,figsize=(5,5)) 
for ax, column in zip(axes,columns):
    sns.boxplot(data=new_df,x=new_df[column] ,width=0.3 , saturation=0.9,orient="h",ax=ax);                                                                           
plt.tight_layout()

# %% [markdown]
# Analisis bivariado

# %%
#Scatterplot con las siguientes variables ['temperatura min hora','presion min hora','velocidad horaria viento','temperatura max hora']
sns.set_style("whitegrid")
sns.scatterplot(new_df,x='temperatura min hora',y='velocidad horaria viento')
# Out:
# <Axes: xlabel='temperatura min hora', ylabel='velocidad horaria viento'>

# %%
sns.set_style("whitegrid")
sns.regplot(new_df,x='temperatura min hora',y='velocidad horaria viento',scatter=False);
plt.xlabel("Temperatura min hora anterior");
plt.ylabel("Velocidad horaria del viento m/s");
plt.title("Temp min VS Velocidad");

# %%
#Scatterplot con las siguientes variables ['presion min hora','velocidad horaria viento','presion atm max']
sns.set_style("whitegrid")
sns.scatterplot(new_df,x='presion min hora',y='velocidad horaria viento')
# Out:
# <Axes: xlabel='presion min hora', ylabel='velocidad horaria viento'>

# %%
sns.set_style("whitegrid")
sns.regplot(new_df,x='presion min hora',y='velocidad horaria viento',scatter=False);
plt.xlabel("Presion atmosferica min.hora");
plt.ylabel("Velocidad horaria del viento m/s");
plt.title("Min Presion VS Velocidad");

# %%
#Scatterplot con las siguientes variables ['viento maximo','presion atm max']
sns.set_style("whitegrid")
sns.scatterplot(new_df,x='viento maximo',y='velocidad horaria viento');

# %%
sns.set_style("whitegrid")
sns.regplot(new_df,x='viento maximo',y='velocidad horaria viento',scatter=False);
plt.xlabel("Viento maximo");
plt.ylabel("Velocidad horaria del viento m/s");
plt.title("Max Wind VS Velocidad");

# %%
#Scatterplot con las siguientes variables ['presion atm max']
sns.set_style("whitegrid")
sns.scatterplot(new_df,x='precipitacion total',y='velocidad horaria viento');

# %%
sns.set_style("whitegrid")
sns.regplot(new_df,x='precipitacion total',y='velocidad horaria viento',scatter=False);
plt.xlabel("Precipitacion total por hora");
plt.ylabel("Velocidad horaria del viento m/s");
plt.title("Prep. total VS Velocidad");

# %% [markdown]
# Reduccion de dimensionalidad

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
new_df= new_df.drop(columns=["hora"],axis=1)

# %%
X = new_df.assign(const=1)  
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(new_df.shape[1])]

print(vif_data)
# Out:
#                      feature        VIF
# 0   direccion horaria viento   1.345699
# 1   velocidad horaria viento   4.748986
# 2       unidad real max hora  78.013674
# 3       unidad real min hora  80.702053
# 4       temperatura max hora  68.491917
# 5       temperatura min hora  57.418520
# 6            unidad relativa  52.754008
# 7                presion atm   4.902439
# 8        precipitacion total   1.150096
# 9              viento maximo   5.076656
# 10           presion atm max  16.003360
# 11          presion min hora  16.412550

# %%
new_df= new_df.drop(columns=["unidad real min hora"],axis=1)
X = new_df.assign(const=1)  
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(new_df.shape[1])]

print(vif_data)
# Out:
#                      feature        VIF
# 0   direccion horaria viento   1.345074
# 1   velocidad horaria viento   4.740648
# 2       unidad real max hora  42.302768
# 3       temperatura max hora  30.626797
# 4       temperatura min hora  26.973884
# 5            unidad relativa  47.105755
# 6                presion atm   4.902339
# 7        precipitacion total   1.150071
# 8              viento maximo   5.069829
# 9            presion atm max  15.985774
# 10          presion min hora  16.408262

# %%
new_df= new_df.drop(columns=["unidad real max hora"],axis=1)
X = new_df.assign(const=1)  
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(new_df.shape[1])]

print(vif_data)
# Out:
#                     feature        VIF
# 0  direccion horaria viento   1.344339
# 1  velocidad horaria viento   4.678710
# 2      temperatura max hora  23.910001
# 3      temperatura min hora  21.440133
# 4           unidad relativa   2.453999
# 5               presion atm   4.902053
# 6       precipitacion total   1.138573
# 7             viento maximo   5.016924
# 8           presion atm max  15.969938
# 9          presion min hora  16.406833

# %%
new_df= new_df.drop(columns=["temperatura max hora"],axis=1)
X = new_df.assign(const=1)  
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(new_df.shape[1])]

print(vif_data)
# Out:
#                     feature        VIF
# 0  direccion horaria viento   1.324768
# 1  velocidad horaria viento   4.610403
# 2      temperatura min hora   2.073612
# 3           unidad relativa   2.238283
# 4               presion atm   4.901520
# 5       precipitacion total   1.112659
# 6             viento maximo   4.869931
# 7           presion atm max  15.600586
# 8          presion min hora  16.058829

# %%
new_df= new_df.drop(columns=["presion atm max"],axis=1)
X = new_df.assign(const=1)  
vif_data = pd.DataFrame()
vif_data["feature"] = new_df.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(new_df.shape[1])]
print(vif_data)
# Out:
#                     feature       VIF
# 0  direccion horaria viento  1.324474
# 1  velocidad horaria viento  4.607677
# 2      temperatura min hora  2.072325
# 3           unidad relativa  2.233059
# 4               presion atm  4.637675
# 5       precipitacion total  1.109236
# 6             viento maximo  4.855292
# 7          presion min hora  4.896527

# %% [markdown]
# 2. Deteccion de fraudes

# %%
load_path2=r"C:\Users\Tripp\Downloads\train_identity.csv"
load_path3=r"C:\Users\Tripp\Downloads\train_transaction1.csv"
df_fraud1= pd.read_csv(load_path2)
df_fraud2=pd.read_csv(load_path3)

# %%
df_fraud1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 41 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  99999 non-null  int64
#  1   id_01          99999 non-null  float64
#  2   id_02          97717 non-null  float64
#  3   id_03          44789 non-null  float64
#  4   id_04          44789 non-null  float64
#  5   id_05          95107 non-null  float64
#  6   id_06          95107 non-null  float64
#  7   id_07          3616 non-null   float64
#  8   id_08          3616 non-null   float64
#  9   id_09          51171 non-null  float64
#  10  id_10          51171 non-null  float64
#  11  id_11          97830 non-null  float64
#  12  id_12          99999 non-null  object
#  13  id_13          86102 non-null  float64
#  14  id_14          60388 non-null  float64
#  15  id_15          97830 non-null  object
#  16  id_16          90820 non-null  object
# ...

# %%
df_fraud2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 394 entries, TransactionID to V339
# dtypes: float64(376), int64(4), object(14)
# memory usage: 300.6+ MB

# %%
new_df_f = pd.merge(df_fraud2,df_fraud1,on="TransactionID",how="left")

# %%
#Numero de observaciones, media, desviacion estandar, minimo, maximo, cuartiles.
new_df_f.describe()
# Out:
#        TransactionID      isFraud  TransactionDT  TransactionAmt  \
# count   9.999900e+04  99999.00000   9.999900e+04    99999.000000
# mean    3.036999e+06      0.02561   1.135115e+06      130.743579
# std     2.886737e+04      0.15797   5.733446e+05      206.025702
# min     2.987000e+06      0.00000   8.640000e+04        0.292000
# 25%     3.012000e+06      0.00000   6.537475e+05       45.000000
# 50%     3.036999e+06      0.00000   1.189336e+06       75.000000
# 75%     3.061998e+06      0.00000   1.643436e+06      135.950000
# max     3.086998e+06      1.00000   2.006177e+06     4829.950000
#
#               card1         card2         card3         card5         addr1  \
# count  99999.000000  98645.000000  99996.000000  99474.000000  90962.000000
# mean    9878.453325    370.887972    153.236709    200.072039    291.414239
# std     4933.557719    159.244484     11.151578     40.905338    103.077427
# ...

# %%
#Conteo de datos faltantes numericamente 
new_df_f.isnull().sum()
# Out:
# TransactionID         0
# isFraud               0
# TransactionDT         0
# TransactionAmt        0
# ProductCD             0
#                   ...
# id_36             59598
# id_37             59598
# id_38             59598
# DeviceType        59716
# DeviceInfo        63534
# Length: 434, dtype: int64

# %%
#Conteo de datos faltantes porcentualmente 
(new_df_f.isnull().sum()/(len(new_df_f)))*100
# Out:
# TransactionID      0.000000
# isFraud            0.000000
# TransactionDT      0.000000
# TransactionAmt     0.000000
# ProductCD          0.000000
#                     ...
# id_36             59.598596
# id_37             59.598596
# id_38             59.598596
# DeviceType        59.716597
# DeviceInfo        63.534635
# Length: 434, dtype: float64

# %%
#Debemos hacer onehhotencoding de las columnas no numericas primero
non_numeric_cols = new_df_f.select_dtypes(exclude="number").columns.tolist()
print(non_numeric_cols)
# Out:
# ['ProductCD', 'card4', 'card6', 'P_emaildomain', 'R_emaildomain', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'id_12', 'id_15', 'id_16', 'id_23', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType', 'DeviceInfo']

# %%
new_df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 434 entries, TransactionID to DeviceInfo
# dtypes: float64(399), int64(4), object(31)
# memory usage: 331.1+ MB

# %%
#Histograma o diagrama de barras para la variable respuesta e independiente ( isfraud))
import seaborn as sns
import matplotlib.pyplot as plt

def annotate_counts(ax):
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 9), 
                    textcoords='offset points')


sns.set_style("whitegrid")
ax= sns.countplot(x="isFraud",data=new_df_f)
plt.xlabel("Fraude")
annotate_counts(ax)

# %% [markdown]
# Se observa un gran desbalance en la cuenta, lo que es normal en este tipo de ejercicios de fraude.

# %%
corr_matrix = new_df_f.drop(["isFraud"], axis=1).corr()
corr_matrix.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tripp\OneDrive\Documentos\MachineLearning\Parcial.ipynb Cell 45 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tripp/OneDrive/Documentos/MachineLearning/Parcial.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> corr_matrix = new_df_f.drop(["isFraud"], axis=1).corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/Tripp/OneDrive/Documentos/MachineLearning/Parcial.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> corr_matrix.shape
#
# File c:\Users\Tripp\miniconda3\envs\ml_venv\lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...
